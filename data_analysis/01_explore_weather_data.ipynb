# %% [markdown]
# # Weather Data Exploration
# This notebook analyzes the retrieved weather data and identifies potential data quality issues.

# %% [markdown]
# ## 1. Setup
# Prepare the environment by importing necessary libraries and setting up input/output directories.

# %%
import os
import ast
import pandas as pd

# %%
# Input/Output directories
RAW_INPUT_DIR = 'data/weather_data/raw'
FULL_OUTPUT_DIR = 'data/weather_data/full'
os.makedirs(FULL_OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# ## 2. Load Raw Weather Data
# Load and combine all raw weather data files into a single DataFrame for analysis.

# %%
# Load all raw weather data files
data_list = os.listdir(RAW_INPUT_DIR)
weather = pd.DataFrame()
for file in data_list:
    if file.endswith('.parquet'):
        file_path = os.path.join(RAW_INPUT_DIR, file)
        temp_df = pd.read_parquet(file_path)
        if not weather.empty:
            weather = pd.concat([weather, temp_df], ignore_index=True)
        else:
            weather = temp_df

print(f"Total records loaded: {len(weather)}")
print(f"Columns: {weather.columns.tolist()}")
# Out:
# Total records loaded: 404430
# Columns: ['geometry.coordinates', 'date_tm-value', 'stn_nam-value', 'avg_wnd_spd_10m_pst10mts', 'avg_wnd_spd_10m_pst1hr', 'air_temp', 'air_temp-qa', 'dwpt_temp', 'rel_hum', 'rel_hum-qa', 'rnfl_amt_pst1mt', 'rnfl_amt_pst1mt-qa', 'rnfl_amt_pst1hr', 'dwpt_temp-qa', 'avg_vis_pst10mts', 'rnfl_amt_pst1hr-qa', 'vis', 'vis-qa']

# %%
weather.head()
# Out:
#                 geometry.coordinates             date_tm-value  \
# 0          [-123.1333, 49.0039, 8.3]  2025-11-18T08:00:00.000Z
# 1         [-122.7839, 49.0181, 13.0]  2025-11-18T08:00:00.000Z
# 2  [-123.193392, 49.347059, 170.885]  2025-11-18T08:00:00.000Z
# 3      [-122.690076, 49.208307, 6.3]  2025-11-18T08:00:00.000Z
# 4          [-122.631, 49.1008, 10.4]  2025-11-18T08:00:00.000Z
#
#            stn_nam-value  avg_wnd_spd_10m_pst10mts  avg_wnd_spd_10m_pst1hr  \
# 0  TSAWWASSEN FERRY AUTO                       4.0                     3.1
# 1             WHITE ROCK                       1.3                     1.1
# 2     WEST VANCOUVER AUT                       2.7                     2.9
# 3        PITT MEADOWS CS                       2.3                     2.6
# 4       Langley Regional                       2.5                     NaN
#
#    air_temp  air_temp-qa  dwpt_temp  rel_hum  rel_hum-qa  rnfl_amt_pst1mt  \
# 0       NaN          NaN        NaN      NaN         NaN              NaN
# 1       6.6        100.0        5.9     95.0       100.0              0.0
# 2       4.9        100.0        4.3     96.0       100.0              0.0
# 3       7.2        100.0        6.7     97.0       100.0              0.0
# 4       6.2        100.0        5.4     95.0       100.0              NaN
#
#    rnfl_amt_pst1mt-qa  rnfl_amt_pst1hr  dwpt_temp-qa  avg_vis_pst10mts  \
# 0                 NaN              NaN           NaN               NaN
# 1               100.0              0.0           NaN               NaN
# 2               100.0              0.0           NaN               NaN
# 3               100.0              0.0           NaN               NaN
# 4                 NaN              NaN         100.0               NaN
#
#    rnfl_amt_pst1hr-qa  vis  vis-qa
# 0                 NaN  NaN     NaN
# 1                 NaN  NaN     NaN
# 2                 NaN  NaN     NaN
# 3                 NaN  NaN     NaN
# 4                 NaN  NaN     NaN

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404430 entries, 0 to 404429
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   geometry.coordinates      404430 non-null  object
#  1   date_tm-value             404430 non-null  object
#  2   stn_nam-value             404430 non-null  object
#  3   avg_wnd_spd_10m_pst10mts  399458 non-null  float64
#  4   avg_wnd_spd_10m_pst1hr    394695 non-null  float64
#  5   air_temp                  337451 non-null  float64
#  6   air_temp-qa               337451 non-null  float64
#  7   dwpt_temp                 337164 non-null  float64
#  8   rel_hum                   337164 non-null  float64
#  9   rel_hum-qa                337451 non-null  float64
#  10  rnfl_amt_pst1mt           257164 non-null  float64
#  11  rnfl_amt_pst1mt-qa        257164 non-null  float64
#  12  rnfl_amt_pst1hr           263844 non-null  float64
#  13  dwpt_temp-qa              7070 non-null    float64
#  14  avg_vis_pst10mts          0 non-null       float64
#  15  rnfl_amt_pst1hr-qa        6680 non-null    float64
#  16  vis                       1377 non-null    float64
#  17  vis-qa                    1377 non-null    float64
# dtypes: float64(15), object(3)
# memory usage: 55.5+ MB

# %% [markdown]
# ## 3. Check Missing Values by Station
# Analyze missing values for key features grouped by station. Identify stations with incomplete or insufficient data, such as missing rainfall measurements.

# %%
cols_to_check = ['vis', 'rnfl_amt_pst1mt', 'rnfl_amt_pst1hr', 'air_temp', 'rel_hum', 'dwpt_temp', 'avg_wnd_spd_10m_pst10mts', 'avg_wnd_spd_10m_pst1hr']

# Calculate the number of null values for each column grouped by station name
result = weather.groupby('stn_nam-value')[cols_to_check].apply(lambda x: x.isnull().sum())
result['total_rows'] = weather.groupby('stn_nam-value').size()
result[['total_rows']+cols_to_check]
# Out:
#                                 total_rows    vis  rnfl_amt_pst1mt  \
# stn_nam-value
# ALEX FRASER BRIDGE                     145    145              145
# ALEX FRASER CROSS BEAM                 143    143              143
# ALEX FRASER TOP                        142    142              142
# ANNACIS ISLAND                         144    144              144
# Annacis Island                         778    778              778
# BRADNER ROAD                           136    136              136
# DELTA BURNS BOG                      65442  65442             1116
# EAGLE RIDGE                            127    127              127
# Langley Regional                      1116   1116             1116
# PITT MEADOWS CS                      65444  65444             1116
# POINT ATKINSON                       65446  65446            65446
# PORT MANN BRIDGE JOHNSTON HILL         142    142              142
# PORT MANN BRIDGE MID SPAN              142    142              142
# Pitt Meadows                          1105   1105             1105
# RICEMILL ROAD                          119    119              119
# Rocky Point Park                       687    687              687
# SANDHEADS CS                          1091   1091             1091
# Second Narrows                          96     96               96
# TSAWWASSEN FERRY AUTO                65418  65418            65418
# VANCOUVER HARBOUR CS                  1104   1104             1104
# VANCOUVER SEA ISLAND CCG              1116   1116             1116
# Vancouver Boundary Bay                1116   1116             1116
# Vancouver Harbour                     1116   1116             1116
# Vancouver International               1377      0             1377
# WEST VANCOUVER AUT                   65295  65295             1112
# WHITE ROCK                           65443  65443             1116
#
#                                 rnfl_amt_pst1hr  air_temp  rel_hum  dwpt_temp  \
# stn_nam-value
# ALEX FRASER BRIDGE                          145         0        0          0
# ALEX FRASER CROSS BEAM                      143         0      143        143
# ALEX FRASER TOP                             142         0        0          0
# ANNACIS ISLAND                              144         0      144        144
# Annacis Island                              778       778      778        778
# BRADNER ROAD                                136         0        0          0
# DELTA BURNS BOG                               0         0        0          0
# EAGLE RIDGE                                 127         0        0          0
# Langley Regional                           1116         0        0          0
# PITT MEADOWS CS                               0         0        0          0
# POINT ATKINSON                            65446         0        0          0
# PORT MANN BRIDGE JOHNSTON HILL              142         0        0          0
# PORT MANN BRIDGE MID SPAN                   142         0        0          0
# Pitt Meadows                               1105         0        0          0
# RICEMILL ROAD                               119         0        0          0
# Rocky Point Park                            687       687      687        687
# SANDHEADS CS                               1091         0        0          0
# Second Narrows                               96        96       96         96
# TSAWWASSEN FERRY AUTO                     65418     65418    65418      65418
# VANCOUVER HARBOUR CS                          0         0        0          0
# VANCOUVER SEA ISLAND CCG                      0         0        0          0
# Vancouver Boundary Bay                     1116         0        0          0
# Vancouver Harbour                          1116         0        0          0
# Vancouver International                    1377         0        0          0
# WEST VANCOUVER AUT                            0         0        0          0
# WHITE ROCK                                    0         0        0          0
#
#                                 avg_wnd_spd_10m_pst10mts  \
# stn_nam-value
# ALEX FRASER BRIDGE                                   145
# ALEX FRASER CROSS BEAM                               143
# ALEX FRASER TOP                                      142
# ANNACIS ISLAND                                       144
# Annacis Island                                       778
# BRADNER ROAD                                         136
# DELTA BURNS BOG                                        0
# EAGLE RIDGE                                          127
# Langley Regional                                       1
# PITT MEADOWS CS                                        0
# POINT ATKINSON                                         0
# PORT MANN BRIDGE JOHNSTON HILL                       142
# PORT MANN BRIDGE MID SPAN                            142
# Pitt Meadows                                           0
# RICEMILL ROAD                                        119
# Rocky Point Park                                     687
# SANDHEADS CS                                           0
# Second Narrows                                        96
# TSAWWASSEN FERRY AUTO                                  0
# VANCOUVER HARBOUR CS                                1104
# VANCOUVER SEA ISLAND CCG                               0
# Vancouver Boundary Bay                                 1
# Vancouver Harbour                                      1
# Vancouver International                             1064
# WEST VANCOUVER AUT                                     0
# WHITE ROCK                                             0
#
#                                 avg_wnd_spd_10m_pst1hr
# stn_nam-value
# ALEX FRASER BRIDGE                                 145
# ALEX FRASER CROSS BEAM                             143
# ALEX FRASER TOP                                    142
# ANNACIS ISLAND                                     144
# Annacis Island                                     778
# BRADNER ROAD                                       136
# DELTA BURNS BOG                                      0
# EAGLE RIDGE                                        127
# Langley Regional                                  1116
# PITT MEADOWS CS                                      0
# POINT ATKINSON                                       0
# PORT MANN BRIDGE JOHNSTON HILL                     142
# PORT MANN BRIDGE MID SPAN                          142
# Pitt Meadows                                      1105
# RICEMILL ROAD                                      119
# Rocky Point Park                                   687
# SANDHEADS CS                                         0
# Second Narrows                                      96
# TSAWWASSEN FERRY AUTO                                0
# VANCOUVER HARBOUR CS                              1104
# VANCOUVER SEA ISLAND CCG                             0
# Vancouver Boundary Bay                            1116
# Vancouver Harbour                                 1116
# Vancouver International                           1377
# WEST VANCOUVER AUT                                   0
# WHITE ROCK                                           0

# %% [markdown]
# ## 4. Identify Stations to Exclude
# Based on the analysis, identify stations to exclude. Since rainfall data is critical for this project, stations with no rainfall measurements are carefully excluded.

# %%
# Identify stations where rnfl_amt_pst1hr is all null
rain_null_check = weather.groupby('stn_nam-value')['rnfl_amt_pst1hr'].apply(lambda x: x.isnull().all())
exclude_stations = rain_null_check[rain_null_check].index.tolist()
exclude_stations = list(set(exclude_stations))

print(f"Stations to exclude (no rainfall data): {exclude_stations}")
# Out:
# Stations to exclude (no rainfall data): ['EAGLE RIDGE', 'ALEX FRASER CROSS BEAM', 'Annacis Island', 'Vancouver International', 'Vancouver Boundary Bay', 'SANDHEADS CS', 'BRADNER ROAD', 'ALEX FRASER BRIDGE', 'Vancouver Harbour', 'Rocky Point Park', 'Pitt Meadows', 'RICEMILL ROAD', 'PORT MANN BRIDGE MID SPAN', 'TSAWWASSEN FERRY AUTO', 'PORT MANN BRIDGE JOHNSTON HILL', 'Second Narrows', 'POINT ATKINSON', 'ANNACIS ISLAND', 'ALEX FRASER TOP', 'Langley Regional']

# %%
# Filter out excluded stations
weather_filtered = weather[~weather['stn_nam-value'].isin(exclude_stations)]
print(f"Records after filtering: {len(weather_filtered)}")
# Out:
# Records after filtering: 263844

# %%
# Calculate the number of null values for each column grouped by station name (after filtering)
result = weather_filtered.groupby('stn_nam-value')[cols_to_check].apply(lambda x: x.isnull().sum())
result['total_rows'] = weather_filtered.groupby('stn_nam-value').size()
result[['total_rows']+cols_to_check]
# Out:
#                           total_rows    vis  rnfl_amt_pst1mt  rnfl_amt_pst1hr  \
# stn_nam-value
# DELTA BURNS BOG                65442  65442             1116                0
# PITT MEADOWS CS                65444  65444             1116                0
# VANCOUVER HARBOUR CS            1104   1104             1104                0
# VANCOUVER SEA ISLAND CCG        1116   1116             1116                0
# WEST VANCOUVER AUT             65295  65295             1112                0
# WHITE ROCK                     65443  65443             1116                0
#
#                           air_temp  rel_hum  dwpt_temp  \
# stn_nam-value
# DELTA BURNS BOG                  0        0          0
# PITT MEADOWS CS                  0        0          0
# VANCOUVER HARBOUR CS             0        0          0
# VANCOUVER SEA ISLAND CCG         0        0          0
# WEST VANCOUVER AUT               0        0          0
# WHITE ROCK                       0        0          0
#
#                           avg_wnd_spd_10m_pst10mts  avg_wnd_spd_10m_pst1hr
# stn_nam-value
# DELTA BURNS BOG                                  0                       0
# PITT MEADOWS CS                                  0                       0
# VANCOUVER HARBOUR CS                          1104                    1104
# VANCOUVER SEA ISLAND CCG                         0                       0
# WEST VANCOUVER AUT                               0                       0
# WHITE ROCK                                       0                       0

# %% [markdown]
# ## 5. Time Bucket Analysis
# Group the data into 10-minute intervals to ensure stable and consistent values for analysis.

# %%
# Avoid SettingWithCopyWarning by using .loc
weather_filtered = weather_filtered.copy()

# Convert to datetime with UTC timezone
weather_filtered['date_tm-value'] = pd.to_datetime(weather_filtered['date_tm-value'], utc=True)

# Convert to local timezone
weather_filtered['local_time'] = weather_filtered['date_tm-value'].dt.tz_convert('America/Vancouver')
weather_filtered['time_bucket'] = weather_filtered['local_time'].dt.floor('10min')

weather_filtered[['date_tm-value', 'local_time', 'time_bucket']].head()
# Out:
#               date_tm-value                local_time  \
# 1 2025-11-18 08:00:00+00:00 2025-11-18 00:00:00-08:00
# 2 2025-11-18 08:00:00+00:00 2025-11-18 00:00:00-08:00
# 3 2025-11-18 08:00:00+00:00 2025-11-18 00:00:00-08:00
# 7 2025-11-18 08:00:00+00:00 2025-11-18 00:00:00-08:00
# 9 2025-11-18 08:00:00+00:00 2025-11-18 00:00:00-08:00
#
#                 time_bucket
# 1 2025-11-18 00:00:00-08:00
# 2 2025-11-18 00:00:00-08:00
# 3 2025-11-18 00:00:00-08:00
# 7 2025-11-18 00:00:00-08:00
# 9 2025-11-18 00:00:00-08:00

# %%
# Check null values after aggregation by time bucket
weather_filtered.groupby(['stn_nam-value', 'time_bucket'])[cols_to_check].mean().isnull().sum()
# Out:
# vis                         24958
# rnfl_amt_pst1mt              1917
# rnfl_amt_pst1hr                 0
# air_temp                        0
# rel_hum                         0
# dwpt_temp                       0
# avg_wnd_spd_10m_pst10mts      955
# avg_wnd_spd_10m_pst1hr        955
# dtype: int64

# %% [markdown]
# ## 6. Extract and Save Station Coordinates
# Extract the longitude and latitude of each weather station to facilitate mapping and integration with other datasets.

# %%
# Extract geometry info
def parse_coordinates(coord):
    """Parse coordinates from string, list, or numpy array."""
    if isinstance(coord, str):
        return ast.literal_eval(coord)
    elif hasattr(coord, 'tolist'):  # numpy array
        return coord.tolist()
    return coord  # already a list

weather_filtered['geometry.coordinates'] = weather_filtered['geometry.coordinates'].apply(parse_coordinates)
station_coords = weather_filtered.groupby('stn_nam-value')['geometry.coordinates'].first()
coords_df = pd.DataFrame(station_coords.tolist(), index=station_coords.index)
coords_df = coords_df.iloc[:, :2]
coords_df.columns = ['lon', 'lat']
coords_df.index.name = 'station_name'
coords_df = coords_df.reset_index()
coords_df
# Out:
#                station_name         lon        lat
# 0           DELTA BURNS BOG -123.002436  49.125992
# 1           PITT MEADOWS CS -122.690076  49.208307
# 2      VANCOUVER HARBOUR CS -123.121687  49.295348
# 3  VANCOUVER SEA ISLAND CCG -123.187254  49.182552
# 4        WEST VANCOUVER AUT -123.193392  49.347059
# 5                WHITE ROCK -122.783900  49.018100

# %%
import folium

# Create a map centered on Vancouver area
center_lat = coords_df['lat'].mean()
center_lon = coords_df['lon'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=10)

# Add markers for each station
for _, row in coords_df.iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=row['station_name'],
        tooltip=row['station_name'],
        icon=folium.Icon(color='blue', icon='cloud')
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52f54a61bd93e0dd051450100602c100 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52f54a61bd93e0dd051450100602c100&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52f54a61bd93e0dd051450100602c100 = L.map(
#                 &quot;map_52f54a61bd93e0dd051450100602c100&quot;,
#                 {
#                     center: [49.19622633333333, -122.9964575],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7db58cdca21e1ec59683be73d5f8356 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b7db58cdca21e1ec59683be73d5f8356.addTo(map_52f54a61bd93e0dd051450100602c100);
#
#
#             var marker_b220449674dfdee55e5648d5e2c98a2e = L.marker(
#                 [49.125992, -123.002436],
#                 {
# }
#             ).addTo(map_52f54a61bd93e0dd051450100602c100);
#
#
#             var icon_bbf623eeb059e3566ee4d1f5aa1013c2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a621d3618254c6aef972329314ff8aee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e228a6362df9f429d995aaf25e610db7 = $(`&lt;div id=&quot;html_e228a6362df9f429d995aaf25e610db7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DELTA BURNS BOG&lt;/div&gt;`)[0];
#                 popup_a621d3618254c6aef972329314ff8aee.setContent(html_e228a6362df9f429d995aaf25e610db7);
#
#
#
#         marker_b220449674dfdee55e5648d5e2c98a2e.bindPopup(popup_a621d3618254c6aef972329314ff8aee)
#         ;
#
#
#
#
#             marker_b220449674dfdee55e5648d5e2c98a2e.bindTooltip(
#                 `&lt;div&gt;
#                      DELTA BURNS BOG
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_b220449674dfdee55e5648d5e2c98a2e.setIcon(icon_bbf623eeb059e3566ee4d1f5aa1013c2);
#
#
#             var marker_8891a7ceb5214229908e6a1fe8eb8115 = L.marker(
#                 [49.208307, -122.690076],
#                 {
# }
#             ).addTo(map_52f54a61bd93e0dd051450100602c100);
#
#
#             var icon_6dfe802292a9d255e9822430a7550873 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_26307b194b6403e26db0d968bce3da4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39df5efd4ef447b0cd8d41c3eb80fa73 = $(`&lt;div id=&quot;html_39df5efd4ef447b0cd8d41c3eb80fa73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PITT MEADOWS CS&lt;/div&gt;`)[0];
#                 popup_26307b194b6403e26db0d968bce3da4f.setContent(html_39df5efd4ef447b0cd8d41c3eb80fa73);
#
#
#
#         marker_8891a7ceb5214229908e6a1fe8eb8115.bindPopup(popup_26307b194b6403e26db0d968bce3da4f)
#         ;
#
#
#
#
#             marker_8891a7ceb5214229908e6a1fe8eb8115.bindTooltip(
#                 `&lt;div&gt;
#                      PITT MEADOWS CS
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_8891a7ceb5214229908e6a1fe8eb8115.setIcon(icon_6dfe802292a9d255e9822430a7550873);
#
#
#             var marker_8a132e30d7d3ce1f6c93987dac288bcc = L.marker(
#                 [49.295348, -123.121687],
#                 {
# }
#             ).addTo(map_52f54a61bd93e0dd051450100602c100);
#
#
#             var icon_6ca55488e68c9c28e87a649ac0d71ba7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5fe823eb7d2cb01552913944b7b50b83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c895678dfdd10e2c1e8068136dd66a8 = $(`&lt;div id=&quot;html_9c895678dfdd10e2c1e8068136dd66a8&quot; style=&quot;width:

# %%
coords_df.to_parquet(f'{FULL_OUTPUT_DIR}/station_coordinates_mst.parquet', index=False)
print(f"Station coordinates saved to {FULL_OUTPUT_DIR}/station_coordinates_mst.parquet")
# Out:
# Station coordinates saved to data/weather_data/full/station_coordinates_mst.parquet

# %% [markdown]
# ## 7. Save Excluded Stations List
# Save the list of excluded stations for reference and use in subsequent processing steps.

# %%
# Save excluded stations list for use in processing notebook
exclude_df = pd.DataFrame({'station_name': exclude_stations})
exclude_df.to_parquet(f'{FULL_OUTPUT_DIR}/excluded_stations.parquet', index=False)
print(f"Excluded stations saved to {FULL_OUTPUT_DIR}/excluded_stations.parquet")
# Out:
# Excluded stations saved to data/weather_data/full/excluded_stations.parquet
